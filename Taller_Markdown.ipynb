# %% [markdown]
# <a href="https://colab.research.google.com/github/jerofax/taller-markdown/blob/main/Taller_Markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # titulo
# ## Subtitulo
# ### Item
#
# **texto en negrita**
# __texto en negrita__
#
# *texto en cursiva*
# _texto en cursiva_
#
# > cita
#
# listas:
#
# ordenadas:
# 1. Primer elemento
# 1. Segundo elemento
#
# no ordenadas:
# * Primer elemento
# * Segundo elemento
#
# + Primer elemento
# + Segundo elemento
#
# - Primer elemento
# - Segundo elemento
#
#
# `código`
#
# Linea horizontal
#
# ---
#
# [Teoria de cuerdas](https://www.agenciasinc.es/Entrevistas/La-teoria-de-cuerdas-es-la-mejor-candidata-para-ofrecer-una-teoria-unificada "título")
#
# ![capibara](data:image/webp;base64,...)

# %% [markdown]
# # HTML
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Cálculo del Mínimo Común Múltiplo (MCM)</title>
#   <script type="text/javascript">
#     function calcularMCM() {
#       var num1 = parseInt(document.getElementById("numero1").value);
#       var num2 = parseInt(document.getElementById("numero2").value);
#
#       var mcm = 0;
#       var max = Math.max(num1, num2);
#
#       while (true) {
#         if (max % num1 === 0 && max % num2 === 0) {
#           mcm = max;
#           break;
#         }
#         max++;
#       }
#
#       document.getElementById("resultado").innerHTML = "El Mínimo Común Múltiplo (MCM) de " + num1 + " y " + num2 + " es: " + mcm;
#     }
#   </script>
# </head>
# <body>
#   <h1>Cálculo del Mínimo Común Múltiplo (MCM)</h1>
#   <label for="numero1">Ingrese el primer número:</label>
#   ```

# %% [markdown]
# JAVASCRIPT
#
# ```javascript
#
# function esPrimo(numero) {
#   for (var i = 2; i < numero; i++) {
#     if (numero % i === 0) {
#       return false;
#     }
#   }
#   return numero !== 1;
# }
#
# function encontrarPrimoEnesimo(n) {
#   var contador = 0;
#   var numeroActual = 2;
#
#   while (contador < n) {
#     if (esPrimo(numeroActual)) {
#       contador++;
#     }
#     numeroActual++;
#   }
#
#   return numeroActual - 1;
# }
#
# var enesimoPrimo = prompt("Ingrese el número primo que desea encontrar:");
# var resultado = encontrarPrimoEnesimo(parseInt(enesimoPrimo));
#
# console.log("El número primo en la posición " + enesimoPrimo + " es: " + resultado);
# ```

# %% [markdown]
# ```json
# {
#   "Jeronimo": "Jeronimo Restrepo Ramirez",
#   "Peso": "60Kg"
# }
# ```

# %% [markdown]
# | Producto | Precio($) |
# | ----------- | ----------- |
# | Manzanas  | 2.50 |
# | Naranjas  | 1.75 |
# | Plátanos   | 0.50|
# | Uvas       | 2.00 |
